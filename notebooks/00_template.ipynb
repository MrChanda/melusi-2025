# %% [markdown]
# ## Session Setup
#
# Run the cell below once at the start of every session. It installs dependencies, mounts Google Drive, clones the repo, and sets file paths.
#
# ### Key Packages
# - **rasterio** — reads/writes raster data (GeoTIFF)
# - **GDAL** — low-level geospatial engine that powers rasterio
# - **geopandas** — extends pandas with geometry support for spatial data
# - **earthpy** — simplified plotting for raster and vector data
# - **contextily** — adds basemap tiles (e.g. satellite/street maps) behind your plots

# %%
# ============ SESSION SETUP (run once per session) ============

# 1. Install/verify packages
# !pip install -q rasterio geopandas GDAL earthpy contextily

# 2. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 3. Git config & clone
# !git config --global user.name "YOUR NAME"
# !git config --global user.email "YOUR EMAIL"

# Set your token here (delete output after running)
TOKEN = "PASTE_YOUR_TOKEN"
# !git clone https://{TOKEN}@github.com/MrChanda/melusi-2025.git /content/melusi-2025 2>/dev/null || echo "Repo already cloned"

# 4. Set paths
DATA_PATH = "/content/drive/MyDrive/MIT/MIT808/melusi-2025-data/raw/"
REPO_PATH = "/content/melusi-2025"

print("✅ Setup complete")

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import rasterio
import geopandas as gpd
import earthpy.plot as ep
import contextily as ctx

# Plot settings
plt.rcParams['figure.figsize'] = (12, 8)
sns.set_style('whitegrid')

# %% [markdown]
# ## Load Data

# %%
# Example: load the GeoTIFF
# with rasterio.open(DATA_PATH + 'your_file.tif') as src:
#     img = src.read()
#     print(src.profile)
